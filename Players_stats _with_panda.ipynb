# %% [markdown]
# <h1> Libraries and files </h1>

# %%
import xml.etree.ElementTree as ET
import time
import pandas as pd
import matplotlib.pyplot as plt
import operator
import numpy as np

tree = ET.parse("Data.XML")

regular_season = pd.read_csv("Data_regular_season.csv")
regular_season = regular_season.set_index('Player')
playoffs = pd.read_csv("Data_playoffs.csv")
playoffs = playoffs.set_index('Player')

# %% [markdown]
# <h3> Root </h3>

# %%
root = tree.getroot()

# %% [markdown]
# <h3> Operations : points </h3>

# %%
def getTotalPoints():
    t = pd.Series(regular_season["Points"] + playoffs["Points"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,10])
    t.plot.bar()
    plt.show()
    return t

def displayPoints():
    i = 0
    for element in total_points.index:
        print(f"{i+1} - {element} : {total_points[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: points </h1>

# %%
start_time_points = time.time()
total_points = getTotalPoints() 
displayPoints()
execution_time_points = time.time()-start_time_points
print("\nExecution time: ", execution_time_points , " seconds.")
# Out:
# 1 - Kareem : 44149
# 2 - Karl_Malone : 41689
# 3 - LeBron : 40998
# 4 - Kobe : 39283
# 5 - MJ : 38279
# 6 - Dirk : 35223
# 7 - Wilt : 35026
# 8 - Shaq : 33846
# 9 - Duncan : 31668
# 10 - Hakeem : 30701
# 11 - Paul_Pierce : 29577
# 12 - Elvin_Hayes : 29507
# 13 - Moses_Malone : 29486
# 14 - Garnett : 28672
# 15 - Robertson : 28620
# 16 - Patrick_Ewing : 27628
# 17 - Charles_Barkley : 26590
# 18 - Allen_Iverson : 26479
# 19 - Robert_Parish : 26154
# 20 - Stockton : 22147
# 21 - Magic : 21408
# 22 - CP3 : 20844
# 23 - Dwight_Howard : 20331
# 24 - Jason_Kidd : 19572
# 25 - Steve_Nash : 19459
# 26 - Bill Russell : 17195
#
# Execution time:  0.4237391948699951  seconds.

# %% [markdown]
# <h3> Operations: assists </h3>

# %%
def getTotalAssists():
    t = pd.Series(regular_season["Assists"]+playoffs["Assists"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayAssists():
    i = 0
    for element in total_assists.index:
        print(f"{i+1}-{element} : {total_assists[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: assists </h1>

# %%
start_time_assists = time.time()
total_assists = getTotalAssists() 
displayAssists()
execution_time_assists = time.time()-start_time_assists
print("Execution time: ", execution_time_assists , " seconds.")
# Out:
# 1-Stockton : 17645
# 2-Jason_Kidd : 13354
# 3-Magic : 12487
# 4-Steve_Nash : 11396
# 5-LeBron : 10985
# 6-Robertson : 10656
# 7-CP3 : 10472
# 8-Kobe : 7346
# 9-MJ : 6655
# 10-Kareem : 6427
# 11-Allen_Iverson : 6049
# 12-Garnett : 5916
# 13-Karl_Malone : 5858
# 14-Wilt : 5316
# 15-Paul_Pierce : 5287
# 16-Duncan : 4989
# 17-Bill Russell : 4870
# 18-Charles_Barkley : 4697
# 19-Dirk : 4011
# 20-Shaq : 3608
# 21-Hakeem : 3516
# 22-Elvin_Hayes : 2583
# 23-Patrick_Ewing : 2490
# 24-Robert_Parish : 2414
# 25-Moses_Malone : 1932
# 26-Dwight_Howard : 1709
# Execution time:  0.3887615203857422  seconds.

# %% [markdown]
# <h2> Operations: rebounds </h2>

# %%
def getTotalRebounds():
    t = pd.Series(regular_season["Rebounds"]+playoffs["Rebounds"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayRebounds():
    i = 0
    for element in total_rebounds.index:
        print(f"{i+1}-{element} : {total_rebounds[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: rebounds </h1>

# %%
start_time_rebounds = time.time()
total_rebounds = getTotalRebounds()
displayRebounds()
execution_time_rebounds = time.time() - start_time_rebounds
print("Execution time: ", execution_time_rebounds , " seconds.")
# Out:
# 1-Wilt : 27837
# 2-Bill Russell : 25724
# 3-Kareem : 19921
# 4-Duncan : 17950
# 5-Elvin_Hayes : 17523
# 6-Moses_Malone : 17507
# 7-Karl_Malone : 17030
# 8-Robert_Parish : 16480
# 9-Garnett : 16196
# 10-Shaq : 15607
# 11-Hakeem : 15369
# 12-Dwight_Howard : 14956
# 13-Charles_Barkley : 14128
# 14-Patrick_Ewing : 13042
# 15-Dirk : 12935
# 16-LeBron : 11475
# 17-Jason_Kidd : 9783
# 18-Paul_Pierce : 8512
# 19-Robertson : 8382
# 20-Kobe : 8166
# 21-Magic : 8024
# 22-MJ : 7824
# 23-CP3 : 5091
# 24-Stockton : 4659
# 25-Steve_Nash : 4064
# 26-Allen_Iverson : 3667
# Execution time:  0.43873023986816406  seconds.

# %% [markdown]
# <h1> Operations : steals </h1>

# %%
def getTotalSteals():
    t = pd.Series(regular_season["Steals"]+playoffs["Steals"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displaySteals():
    i = 0
    for element in total_steals.index:
        print(f"{i+1}-{element} : {total_steals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: steals </h1>

# %%
start_time_steals = time.time()
total_steals = getTotalSteals()
displaySteals()
execution_time_steals = time.time() - start_time_steals
print("Execution time: ", execution_time_steals , " seconds.")
# Out:
# 1-Stockton : 3603
# 2-Jason_Kidd : 2986
# 3-CP3 : 2442
# 4-LeBron : 2430
# 5-Hakeem : 2407
# 6-Karl_Malone : 2343
# 7-MJ : 2320
# 8-Kobe : 2254
# 9-Allen_Iverson : 2130
# 10-Magic : 2082
# 11-Garnett : 2037
# 12-Paul_Pierce : 1956
# 13-Elvin_Hayes : 1868
# 14-Charles_Barkley : 1841
# 15-Robert_Parish : 1364
# 16-Dirk : 1359
# 17-Kareem : 1349
# 18-Patrick_Ewing : 1258
# 19-Duncan : 1193
# 20-Moses_Malone : 1173
# 21-Dwight_Howard : 1097
# 22-Steve_Nash : 965
# 23-Shaq : 856
# 24-Robertson : 92
# 25-Wilt : 0
# 26-Bill Russell : 0
# Execution time:  0.507683277130127  seconds.

# %% [markdown]
# <h1> Operations : blocks </h1>

# %%
def getTotalBlocks():
    t = pd.Series(regular_season["Blocks"]+playoffs["Blocks"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayBlocks():
    i = 0
    for element in total_blocks.index:
        print(f"{i+1}-{element} : {total_blocks[i]}")
        i+=1

# %% [markdown]
# <h1> Stats : blocks </h1>

# %%
start_time_blocks = time.time()
total_blocks = getTotalBlocks()
displayBlocks()
execution_time_blocks = time.time()-start_time_blocks
print("Execution time: ", execution_time_blocks , " seconds.")
# Out:
# 1-Hakeem : 4065
# 2-Kareem : 3665
# 3-Duncan : 3588
# 4-Patrick_Ewing : 3197
# 5-Shaq : 3191
# 6-Robert_Parish : 2670
# 7-Dwight_Howard : 2361
# 8-Garnett : 2223
# 9-Moses_Malone : 1884
# 10-Dirk : 1410
# 11-Karl_Malone : 1280
# 12-LeBron : 1183
# 13-Elvin_Hayes : 1086
# 14-MJ : 1051
# 15-Charles_Barkley : 996
# 16-Paul_Pierce : 850
# 17-Kobe : 784
# 18-Jason_Kidd : 502
# 19-Magic : 438
# 20-Stockton : 365
# 21-Allen_Iverson : 178
# 22-CP3 : 149
# 23-Steve_Nash : 116
# 24-Robertson : 8
# 25-Bill Russell : 0
# 26-Wilt : 0
# Execution time:  0.5726473331451416  seconds.

# %% [markdown]
# <h1> Operations: totals </h1>

# %%
def getTotalTotals():
    t = pd.Series(total_points+total_assists+total_rebounds+total_steals+total_blocks)
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayTotals():
    i = 0
    for element in total_totals.index:
        print(f"{i+1}-{element} : {total_totals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: totals </h1>

# %%
start_time_totals = time.time()
total_totals = getTotalTotals()
displayTotals()
execution_time_totals = time.time()-start_time_totals
print("Execution time: ", execution_time_totals, " seconds.")
# Out:
# 1-Kareem : 75511
# 2-Karl_Malone : 68200
# 3-Wilt : 68179
# 4-LeBron : 67071
# 5-Duncan : 59388
# 6-Kobe : 57833
# 7-Shaq : 57108
# 8-MJ : 56129
# 9-Hakeem : 56058
# 10-Garnett : 55044
# 11-Dirk : 54938
# 12-Elvin_Hayes : 52567
# 13-Moses_Malone : 51982
# 14-Robert_Parish : 49082
# 15-Stockton : 48419
# 16-Charles_Barkley : 48252
# 17-Bill Russell : 47789
# 18-Robertson : 47758
# 19-Patrick_Ewing : 47615
# 20-Jason_Kidd : 46197
# 21-Paul_Pierce : 46182
# 22-Magic : 44439
# 23-Dwight_Howard : 40454
# 24-CP3 : 38998
# 25-Allen_Iverson : 38503
# 26-Steve_Nash : 36000
# Execution time:  0.47470569610595703  seconds.

# %%
print("Total execution time: ", execution_time_points+execution_time_assists+execution_time_rebounds+execution_time_steals+execution_time_blocks+execution_time_totals, " seconds.")
# Out:
# Total execution time:  2.806267261505127  seconds.
