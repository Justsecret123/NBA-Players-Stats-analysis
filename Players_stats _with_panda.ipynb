# %% [markdown]
# <h1> Libraries and files </h1>

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import operator
import numpy as np


regular_season = pd.read_csv("Data_regular_season.csv")
regular_season = regular_season.set_index('Player')
playoffs = pd.read_csv("Data_playoffs.csv")
playoffs = playoffs.set_index('Player')

# %% [markdown]
# <h3> Operations : points </h3>

# %%
def getTotalPoints():
    t = pd.Series(regular_season["Points"] + playoffs["Points"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,10])
    t.plot.bar()
    plt.show()
    return t

def displayPoints():
    i = 0
    for element in total_points.index:
        print(f"{i+1} - {element} : {total_points[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: points </h1>

# %%
start_time_points = time.time()
total_points = getTotalPoints() 
displayPoints()
execution_time_points = time.time()-start_time_points
print("\nExecution time: ", execution_time_points , " seconds.")
# Out:
# 1 - Kareem : 44149
# 2 - Karl_Malone : 41689
# 3 - LeBron : 40998
# 4 - Kobe : 39283
# 5 - MJ : 38279
# 6 - Dirk : 35223
# 7 - Wilt : 35026
# 8 - Julius_Erving : 34606
# 9 - Shaq : 33846
# 10 - Duncan : 31668
# 11 - Hakeem : 30701
# 12 - Jerry_West : 29649
# 13 - Paul_Pierce : 29577
# 14 - Elvin_Hayes : 29507
# 15 - Moses_Malone : 29486
# 16 - Garnett : 28672
# 17 - Robertson : 28620
# 18 - Dominique_Wikins : 28091
# 19 - Patrick_Ewing : 27628
# 20 - Kevin_Durant : 26983
# 21 - Charles_Barkley : 26590
# 22 - Allen_Iverson : 26479
# 23 - Robert_Parish : 26154
# 24 - Russell_Westbrook : 22804
# 25 - Stockton : 22147
# 26 - Magic : 21408
# 27 - CP3 : 20844
# 28 - Dwight_Howard : 20331
# 29 - Jason_Kidd : 19572
# 30 - Steve_Nash : 19459
# 31 - Steph_Curry : 19387
# 32 - Bill Russell : 17195
# 33 - Anthony_Davis : 12923
# 34 - Kawhi_Leonard : 11784
#
# Execution time:  0.48270249366760254  seconds.

# %% [markdown]
# <h3> Operations: assists </h3>

# %%
def getTotalAssists():
    t = pd.Series(regular_season["Assists"]+playoffs["Assists"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayAssists():
    i = 0
    for element in total_assists.index:
        print(f"{i+1}-{element} : {total_assists[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: assists </h1>

# %%
start_time_assists = time.time()
total_assists = getTotalAssists() 
displayAssists()
execution_time_assists = time.time()-start_time_assists
print("Execution time: ", execution_time_assists , " seconds.")
# Out:
# 1-Stockton : 17645
# 2-Jason_Kidd : 13354
# 3-Magic : 12487
# 4-Steve_Nash : 11396
# 5-LeBron : 10985
# 6-Robertson : 10656
# 7-CP3 : 10472
# 8-Russell_Westbrook : 8045
# 9-Kobe : 7346
# 10-Jerry_West : 7208
# 11-MJ : 6655
# 12-Kareem : 6427
# 13-Allen_Iverson : 6049
# 14-Julius_Erving : 6017
# 15-Garnett : 5916
# 16-Karl_Malone : 5858
# 17-Steph_Curry : 5325
# 18-Wilt : 5316
# 19-Paul_Pierce : 5287
# 20-Duncan : 4989
# 21-Bill Russell : 4870
# 22-Charles_Barkley : 4697
# 23-Kevin_Durant : 4043
# 24-Dirk : 4011
# 25-Shaq : 3608
# 26-Hakeem : 3516
# 27-Dominique_Wikins : 2820
# 28-Elvin_Hayes : 2583
# 29-Patrick_Ewing : 2490
# 30-Robert_Parish : 2414
# 31-Moses_Malone : 1932
# 32-Dwight_Howard : 1709
# 33-Kawhi_Leonard : 1640
# 34-Anthony_Davis : 1177
# Execution time:  0.4657118320465088  seconds.

# %% [markdown]
# <h2> Operations: rebounds </h2>

# %%
def getTotalRebounds():
    t = pd.Series(regular_season["Rebounds"]+playoffs["Rebounds"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayRebounds():
    i = 0
    for element in total_rebounds.index:
        print(f"{i+1}-{element} : {total_rebounds[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: rebounds </h1>

# %%
start_time_rebounds = time.time()
total_rebounds = getTotalRebounds()
displayRebounds()
execution_time_rebounds = time.time() - start_time_rebounds
print("Execution time: ", execution_time_rebounds , " seconds.")
# Out:
# 1-Wilt : 27837
# 2-Bill Russell : 25724
# 3-Kareem : 19921
# 4-Duncan : 17950
# 5-Elvin_Hayes : 17523
# 6-Moses_Malone : 17507
# 7-Karl_Malone : 17030
# 8-Robert_Parish : 16480
# 9-Garnett : 16196
# 10-Shaq : 15607
# 11-Hakeem : 15369
# 12-Dwight_Howard : 14956
# 13-Charles_Barkley : 14128
# 14-Patrick_Ewing : 13042
# 15-Dirk : 12935
# 16-Julius_Erving : 12136
# 17-LeBron : 11475
# 18-Jason_Kidd : 9783
# 19-Paul_Pierce : 8512
# 20-Robertson : 8382
# 21-Kobe : 8166
# 22-Magic : 8024
# 23-MJ : 7824
# 24-Dominique_Wikins : 7544
# 25-Kevin_Durant : 7063
# 26-Russell_Westbrook : 6872
# 27-Jerry_West : 6231
# 28-Anthony_Davis : 5587
# 29-CP3 : 5091
# 30-Stockton : 4659
# 31-Kawhi_Leonard : 4177
# 32-Steve_Nash : 4064
# 33-Steph_Curry : 3762
# 34-Allen_Iverson : 3667
# Execution time:  0.6356098651885986  seconds.

# %% [markdown]
# <h1> Operations : steals </h1>

# %%
def getTotalSteals():
    t = pd.Series(regular_season["Steals"]+playoffs["Steals"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displaySteals():
    i = 0
    for element in total_steals.index:
        print(f"{i+1}-{element} : {total_steals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: steals </h1>

# %%
start_time_steals = time.time()
total_steals = getTotalSteals()
displaySteals()
execution_time_steals = time.time() - start_time_steals
print("Execution time: ", execution_time_steals , " seconds.")
# Out:
# 1-Stockton : 3603
# 2-Jason_Kidd : 2986
# 3-Julius_Erving : 2559
# 4-CP3 : 2442
# 5-LeBron : 2430
# 6-Hakeem : 2407
# 7-Karl_Malone : 2343
# 8-MJ : 2320
# 9-Kobe : 2254
# 10-Allen_Iverson : 2130
# 11-Magic : 2082
# 12-Garnett : 2037
# 13-Paul_Pierce : 1956
# 14-Elvin_Hayes : 1868
# 15-Charles_Barkley : 1841
# 16-Russell_Westbrook : 1714
# 17-Dominique_Wikins : 1451
# 18-Steph_Curry : 1386
# 19-Robert_Parish : 1364
# 20-Dirk : 1359
# 21-Kareem : 1349
# 22-Patrick_Ewing : 1258
# 23-Duncan : 1193
# 24-Moses_Malone : 1173
# 25-Kawhi_Leonard : 1108
# 26-Dwight_Howard : 1097
# 27-Kevin_Durant : 1087
# 28-Steve_Nash : 965
# 29-Shaq : 856
# 30-Anthony_Davis : 744
# 31-Robertson : 92
# 32-Jerry_West : 81
# 33-Wilt : 0
# 34-Bill Russell : 0
# Execution time:  0.694572925567627  seconds.

# %% [markdown]
# <h1> Operations : blocks </h1>

# %%
def getTotalBlocks():
    t = pd.Series(regular_season["Blocks"]+playoffs["Blocks"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayBlocks():
    i = 0
    for element in total_blocks.index:
        print(f"{i+1}-{element} : {total_blocks[i]}")
        i+=1

# %% [markdown]
# <h1> Stats : blocks </h1>

# %%
start_time_blocks = time.time()
total_blocks = getTotalBlocks()
displayBlocks()
execution_time_blocks = time.time()-start_time_blocks
print("Execution time: ", execution_time_blocks , " seconds.")
# Out:
# 1-Hakeem : 4065
# 2-Kareem : 3665
# 3-Duncan : 3588
# 4-Patrick_Ewing : 3197
# 5-Shaq : 3191
# 6-Robert_Parish : 2670
# 7-Dwight_Howard : 2361
# 8-Julius_Erving : 2234
# 9-Garnett : 2223
# 10-Moses_Malone : 1884
# 11-Dirk : 1410
# 12-Anthony_Davis : 1288
# 13-Karl_Malone : 1280
# 14-LeBron : 1183
# 15-Kevin_Durant : 1104
# 16-Elvin_Hayes : 1086
# 17-MJ : 1051
# 18-Charles_Barkley : 996
# 19-Paul_Pierce : 850
# 20-Kobe : 784
# 21-Dominique_Wikins : 677
# 22-Jason_Kidd : 502
# 23-Magic : 438
# 24-Kawhi_Leonard : 416
# 25-Stockton : 365
# 26-Russell_Westbrook : 295
# 27-Steph_Curry : 186
# 28-Allen_Iverson : 178
# 29-CP3 : 149
# 30-Steve_Nash : 116
# 31-Jerry_West : 23
# 32-Robertson : 8
# 33-Wilt : 0
# 34-Bill Russell : 0
# Execution time:  0.6795713901519775  seconds.

# %% [markdown]
# <h1> Operations: totals </h1>

# %%
def getTotalTotals():
    t = pd.Series(total_points+total_assists+total_rebounds+total_steals+total_blocks)
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayTotals():
    i = 0
    for element in total_totals.index:
        print(f"{i+1}-{element} : {total_totals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: totals </h1>

# %%
start_time_totals = time.time()
total_totals = getTotalTotals()
displayTotals()
execution_time_totals = time.time()-start_time_totals
print("Execution time: ", execution_time_totals, " seconds.")
# Out:
# 1-Kareem : 75511
# 2-Karl_Malone : 68200
# 3-Wilt : 68179
# 4-LeBron : 67071
# 5-Duncan : 59388
# 6-Kobe : 57833
# 7-Julius_Erving : 57552
# 8-Shaq : 57108
# 9-MJ : 56129
# 10-Hakeem : 56058
# 11-Garnett : 55044
# 12-Dirk : 54938
# 13-Elvin_Hayes : 52567
# 14-Moses_Malone : 51982
# 15-Robert_Parish : 49082
# 16-Stockton : 48419
# 17-Charles_Barkley : 48252
# 18-Bill Russell : 47789
# 19-Robertson : 47758
# 20-Patrick_Ewing : 47615
# 21-Jason_Kidd : 46197
# 22-Paul_Pierce : 46182
# 23-Magic : 44439
# 24-Jerry_West : 43192
# 25-Dominique_Wikins : 40583
# 26-Dwight_Howard : 40454
# 27-Kevin_Durant : 40280
# 28-Russell_Westbrook : 39730
# 29-CP3 : 38998
# 30-Allen_Iverson : 38503
# 31-Steve_Nash : 36000
# 32-Steph_Curry : 30046
# 33-Anthony_Davis : 21719
# 34-Kawhi_Leonard : 19125
# Execution time:  0.6835787296295166  seconds.

# %%
print("Total execution time: ", execution_time_points+execution_time_assists+execution_time_rebounds+execution_time_steals+execution_time_blocks+execution_time_totals, " seconds.")
# Out:
# Total execution time:  3.641747236251831  seconds.
