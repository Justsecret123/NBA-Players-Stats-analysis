# %% [markdown]
# <h1> Libraries and files </h1>

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import operator
import numpy as np


regular_season = pd.read_csv("Data_regular_season.csv")
regular_season = regular_season.set_index('Player')
playoffs = pd.read_csv("Data_playoffs.csv")
playoffs = playoffs.set_index('Player')

# %% [markdown]
# <h3> Operations : points </h3>

# %%
def getTotalPoints():
    t = pd.Series(regular_season["Points"] + playoffs["Points"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,10])
    t.plot.bar()
    plt.show()
    return t

def displayPoints():
    i = 0
    for element in total_points.index:
        print(f"{i+1} - {element} : {total_points[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: points </h1>

# %%
start_time_points = time.time()
total_points = getTotalPoints() 
displayPoints()
execution_time_points = time.time()-start_time_points
print("\nExecution time: ", execution_time_points , " seconds.")
# Out:
# 1 - Kareem : 44149
# 2 - LeBron : 41732
# 3 - Karl_Malone : 41689
# 4 - Kobe : 39283
# 5 - MJ : 38279
# 6 - Dirk : 35223
# 7 - Wilt : 35026
# 8 - Julius_Erving : 34606
# 9 - Shaq : 33846
# 10 - Duncan : 31668
# 11 - Hakeem : 30701
# 12 - John_Havlicek : 30171
# 13 - Jerry_West : 29649
# 14 - Paul_Pierce : 29577
# 15 - Elvin_Hayes : 29507
# 16 - Moses_Malone : 29486
# 17 - Garnett : 28672
# 18 - Robertson : 28620
# 19 - Rick_Barry : 28149
# 20 - Dominique_Wikins : 28091
# 21 - Carmelo_Anthony : 28078
# 22 - Patrick_Ewing : 27628
# 23 - Dwyane_Wade : 27119
# 24 - Kevin_Durant : 26983
# 25 - Elgin_Baylor : 26772
# 26 - Artis_Gilmore : 26709
# 27 - Charles_Barkley : 26590
# 28 - Allen_Iverson : 26479
# 29 - Robert_Parish : 26154
# 30 - Larry_Bird : 25688
# 31 - Tony_Parker : 23518
# 32 - David_Robinson : 23011
# 33 - Russell_Westbrook : 22804
# 34 - Stockton : 22147
# 35 - Walt_Bellamy : 21791
# 36 - Magic : 21408
# 37 - CP3 : 20844
# 38 - Kevin_McHale : 20517
# 39 - Dwight_Howard : 20331
# 40 - Jason_Kidd : 19572
# 41 - Steve_Nash : 19459
# 42 - Steph_Curry : 19387
# 43 - Bill Russell : 17195
# 44 - Nate_Thurmond : 15403
# 45 - Anthony_Davis : 13656
# 46 - Kawhi_Leonard : 12324
# 47 - Wes_Unseld : 11884
#
# Execution time:  0.6430985927581787  seconds.

# %% [markdown]
# <h3> Operations: assists </h3>

# %%
def getTotalAssists():
    t = pd.Series(regular_season["Assists"]+playoffs["Assists"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayAssists():
    i = 0
    for element in total_assists.index:
        print(f"{i+1}-{element} : {total_assists[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: assists </h1>

# %%
start_time_assists = time.time()
total_assists = getTotalAssists() 
displayAssists()
execution_time_assists = time.time()-start_time_assists
print("Execution time: ", execution_time_assists , " seconds.")
# Out:
# 1-Stockton : 17645
# 2-Jason_Kidd : 13354
# 3-Magic : 12487
# 4-Steve_Nash : 11396
# 5-LeBron : 11217
# 6-Robertson : 10656
# 7-CP3 : 10472
# 8-Tony_Parker : 8179
# 9-Russell_Westbrook : 8045
# 10-Kobe : 7346
# 11-Jerry_West : 7208
# 12-John_Havlicek : 6939
# 13-Larry_Bird : 6757
# 14-MJ : 6655
# 15-Dwyane_Wade : 6571
# 16-Kareem : 6427
# 17-Allen_Iverson : 6049
# 18-Julius_Erving : 6017
# 19-Garnett : 5916
# 20-Karl_Malone : 5858
# 21-Rick_Barry : 5408
# 22-Steph_Curry : 5325
# 23-Wilt : 5316
# 24-Paul_Pierce : 5287
# 25-Duncan : 4989
# 26-Bill Russell : 4870
# 27-Charles_Barkley : 4697
# 28-Wes_Unseld : 4275
# 29-Elgin_Baylor : 4191
# 30-Kevin_Durant : 4043
# 31-Dirk : 4011
# 32-Shaq : 3608
# 33-Hakeem : 3516
# 34-Carmelo_Anthony : 3429
# 35-Artis_Gilmore : 3282
# 36-Dominique_Wikins : 2820
# 37-Nate_Thurmond : 2802
# 38-David_Robinson : 2721
# 39-Walt_Bellamy : 2680
# 40-Elvin_Hayes : 2583
# 41-Patrick_Ewing : 2490
# 42-Robert_Parish : 2414
# 43-Kevin_McHale : 1944
# 44-Moses_Malone : 1932
# 45-Kawhi_Leonard : 1738
# 46-Dwight_Howard : 1709
# 47-Anthony_Davis : 1278
# Execution time:  0.6880924701690674  seconds.

# %% [markdown]
# <h2> Operations: rebounds </h2>

# %%
def getTotalRebounds():
    t = pd.Series(regular_season["Rebounds"]+playoffs["Rebounds"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayRebounds():
    i = 0
    for element in total_rebounds.index:
        print(f"{i+1}-{element} : {total_rebounds[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: rebounds </h1>

# %%
start_time_rebounds = time.time()
total_rebounds = getTotalRebounds()
displayRebounds()
execution_time_rebounds = time.time() - start_time_rebounds
print("Execution time: ", execution_time_rebounds , " seconds.")
# Out:
# 1-Wilt : 27837
# 2-Bill Russell : 25724
# 3-Kareem : 19921
# 4-Duncan : 17950
# 5-Artis_Gilmore : 17597
# 6-Elvin_Hayes : 17523
# 7-Moses_Malone : 17507
# 8-Karl_Malone : 17030
# 9-Robert_Parish : 16480
# 10-Garnett : 16196
# 11-Shaq : 15607
# 12-Nate_Thurmond : 15565
# 13-Wes_Unseld : 15546
# 14-Hakeem : 15369
# 15-Dwight_Howard : 14956
# 16-Walt_Bellamy : 14921
# 17-Charles_Barkley : 14128
# 18-Elgin_Baylor : 13187
# 19-Patrick_Ewing : 13042
# 20-Dirk : 12935
# 21-Julius_Erving : 12136
# 22-David_Robinson : 11798
# 23-LeBron : 11753
# 24-Larry_Bird : 10657
# 25-Jason_Kidd : 9783
# 26-John_Havlicek : 9193
# 27-Paul_Pierce : 8512
# 28-Robertson : 8382
# 29-Kevin_McHale : 8375
# 30-Kobe : 8166
# 31-Magic : 8024
# 32-MJ : 7824
# 33-Carmelo_Anthony : 7764
# 34-Dominique_Wikins : 7544
# 35-Rick_Barry : 7538
# 36-Kevin_Durant : 7063
# 37-Russell_Westbrook : 6872
# 38-Jerry_West : 6231
# 39-Dwyane_Wade : 5861
# 40-Anthony_Davis : 5852
# 41-CP3 : 5091
# 42-Stockton : 4659
# 43-Kawhi_Leonard : 4327
# 44-Steve_Nash : 4064
# 45-Tony_Parker : 4062
# 46-Steph_Curry : 3762
# 47-Allen_Iverson : 3667
# Execution time:  0.6941797733306885  seconds.

# %% [markdown]
# <h1> Operations : steals </h1>

# %%
def getTotalSteals():
    t = pd.Series(regular_season["Steals"]+playoffs["Steals"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displaySteals():
    i = 0
    for element in total_steals.index:
        print(f"{i+1}-{element} : {total_steals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: steals </h1>

# %%
start_time_steals = time.time()
total_steals = getTotalSteals()
displaySteals()
execution_time_steals = time.time() - start_time_steals
print("Execution time: ", execution_time_steals , " seconds.")
# Out:
# 1-Stockton : 3603
# 2-Jason_Kidd : 2986
# 3-Julius_Erving : 2559
# 4-LeBron : 2460
# 5-CP3 : 2442
# 6-Hakeem : 2407
# 7-Karl_Malone : 2343
# 8-MJ : 2320
# 9-Kobe : 2254
# 10-Allen_Iverson : 2130
# 11-Magic : 2082
# 12-Garnett : 2037
# 13-Paul_Pierce : 1956
# 14-Dwyane_Wade : 1893
# 15-Elvin_Hayes : 1868
# 16-Larry_Bird : 1852
# 17-Charles_Barkley : 1841
# 18-Russell_Westbrook : 1714
# 19-David_Robinson : 1539
# 20-Dominique_Wikins : 1451
# 21-Steph_Curry : 1386
# 22-Robert_Parish : 1364
# 23-Dirk : 1359
# 24-Kareem : 1349
# 25-Patrick_Ewing : 1258
# 26-Tony_Parker : 1251
# 27-Carmelo_Anthony : 1214
# 28-Rick_Barry : 1210
# 29-Duncan : 1193
# 30-Moses_Malone : 1173
# 31-Kawhi_Leonard : 1149
# 32-Dwight_Howard : 1097
# 33-Kevin_Durant : 1087
# 34-Steve_Nash : 965
# 35-Shaq : 856
# 36-Anthony_Davis : 779
# 37-Artis_Gilmore : 708
# 38-Wes_Unseld : 695
# 39-John_Havlicek : 536
# 40-Kevin_McHale : 409
# 41-Nate_Thurmond : 136
# 42-Robertson : 92
# 43-Jerry_West : 81
# 44-Walt_Bellamy : 52
# 45-Wilt : 0
# 46-Elgin_Baylor : 0
# 47-Bill Russell : 0
# Execution time:  0.736966609954834  seconds.

# %% [markdown]
# <h1> Operations : blocks </h1>

# %%
def getTotalBlocks():
    t = pd.Series(regular_season["Blocks"]+playoffs["Blocks"])
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayBlocks():
    i = 0
    for element in total_blocks.index:
        print(f"{i+1}-{element} : {total_blocks[i]}")
        i+=1

# %% [markdown]
# <h1> Stats : blocks </h1>

# %%
start_time_blocks = time.time()
total_blocks = getTotalBlocks()
displayBlocks()
execution_time_blocks = time.time()-start_time_blocks
print("Execution time: ", execution_time_blocks , " seconds.")
# Out:
# 1-Hakeem : 4065
# 2-Kareem : 3665
# 3-Duncan : 3588
# 4-Artis_Gilmore : 3346
# 5-David_Robinson : 3266
# 6-Patrick_Ewing : 3197
# 7-Shaq : 3191
# 8-Robert_Parish : 2670
# 9-Dwight_Howard : 2361
# 10-Julius_Erving : 2234
# 11-Garnett : 2223
# 12-Kevin_McHale : 1971
# 13-Moses_Malone : 1884
# 14-Dirk : 1410
# 15-Anthony_Davis : 1327
# 16-Karl_Malone : 1280
# 17-LeBron : 1207
# 18-Kevin_Durant : 1104
# 19-Elvin_Hayes : 1086
# 20-Dwyane_Wade : 1060
# 21-MJ : 1051
# 22-Charles_Barkley : 996
# 23-Larry_Bird : 900
# 24-Paul_Pierce : 850
# 25-Kobe : 784
# 26-Dominique_Wikins : 677
# 27-Nate_Thurmond : 604
# 28-Carmelo_Anthony : 576
# 29-Jason_Kidd : 502
# 30-Magic : 438
# 31-Kawhi_Leonard : 429
# 32-Wes_Unseld : 422
# 33-Stockton : 365
# 34-Rick_Barry : 308
# 35-Russell_Westbrook : 295
# 36-Steph_Curry : 186
# 37-Allen_Iverson : 178
# 38-CP3 : 149
# 39-John_Havlicek : 133
# 40-Tony_Parker : 117
# 41-Steve_Nash : 116
# 42-Walt_Bellamy : 48
# 43-Jerry_West : 23
# 44-Robertson : 8
# 45-Wilt : 0
# 46-Elgin_Baylor : 0
# 47-Bill Russell : 0
# Execution time:  0.6441574096679688  seconds.

# %% [markdown]
# <h1> Operations: totals </h1>

# %%
def getTotalTotals():
    t = pd.Series(total_points+total_assists+total_rebounds+total_steals+total_blocks)
    t = t.sort_values(ascending=False)
    plt.figure(figsize=[10,8])
    t.plot.bar()
    plt.show()
    return t

def displayTotals():
    i = 0
    for element in total_totals.index:
        print(f"{i+1}-{element} : {total_totals[i]}")
        i+=1

# %% [markdown]
# <h1> Stats: totals </h1>

# %%
start_time_totals = time.time()
total_totals = getTotalTotals()
displayTotals()
execution_time_totals = time.time()-start_time_totals
print("Execution time: ", execution_time_totals, " seconds.")
# Out:
# 1-Kareem : 75511
# 2-LeBron : 68369
# 3-Karl_Malone : 68200
# 4-Wilt : 68179
# 5-Duncan : 59388
# 6-Kobe : 57833
# 7-Julius_Erving : 57552
# 8-Shaq : 57108
# 9-MJ : 56129
# 10-Hakeem : 56058
# 11-Garnett : 55044
# 12-Dirk : 54938
# 13-Elvin_Hayes : 52567
# 14-Moses_Malone : 51982
# 15-Artis_Gilmore : 51642
# 16-Robert_Parish : 49082
# 17-Stockton : 48419
# 18-Charles_Barkley : 48252
# 19-Bill Russell : 47789
# 20-Robertson : 47758
# 21-Patrick_Ewing : 47615
# 22-John_Havlicek : 46972
# 23-Jason_Kidd : 46197
# 24-Paul_Pierce : 46182
# 25-Larry_Bird : 45854
# 26-Magic : 44439
# 27-Elgin_Baylor : 44150
# 28-Jerry_West : 43192
# 29-Rick_Barry : 42613
# 30-Dwyane_Wade : 42504
# 31-David_Robinson : 42335
# 32-Carmelo_Anthony : 41061
# 33-Dominique_Wikins : 40583
# 34-Dwight_Howard : 40454
# 35-Kevin_Durant : 40280
# 36-Russell_Westbrook : 39730
# 37-Walt_Bellamy : 39492
# 38-CP3 : 38998
# 39-Allen_Iverson : 38503
# 40-Tony_Parker : 37127
# 41-Steve_Nash : 36000
# 42-Nate_Thurmond : 34510
# 43-Kevin_McHale : 33216
# 44-Wes_Unseld : 32822
# 45-Steph_Curry : 30046
# 46-Anthony_Davis : 22892
# 47-Kawhi_Leonard : 19967
# Execution time:  0.6574604511260986  seconds.

# %%
print("Total execution time: ", execution_time_points+execution_time_assists+execution_time_rebounds+execution_time_steals+execution_time_blocks+execution_time_totals, " seconds.")
# Out:
# Total execution time:  4.063955307006836  seconds.
