# %% [markdown]
# <h1> <center> How to use ?  </center> <h1>

# %% [markdown]
# Run all the cells, then fill the regular season & the playoffs input fields.

# %% [markdown]
# <h1> Enter a new player </h1>

# %% [markdown]
# <h3> Insert a player name </h3>

# %%
name = str(input("Player's name: "))
# Out:
# Player's name: Ray_Allen

# %% [markdown]
# <h3> Regular season </h3>

# %%
print("\nRegular season: ")
rs_points = int(input("\tPoints: "))
rs_assists = int(input("\tAssists: "))
rs_rebounds = int(input("\tRebounds: "))
rs_steals = int(input("\tSteals: "))
rs_blocks = int(input("\tBlocks: "))
primary_position = int(input("\tPrimary position"))
# Out:
# Regular season:
# 	Points: 24505
# 	Assists: 4361
# 	Rebounds: 5272
# 	Steals: 1451
# 	Blocks: 244
# 	Primary position2

# %% [markdown]
# <h3> Playoffs </h3>

# %%
print("\nPlayoffs: ")
po_points = int(input("\tPoints: "))
po_assists = int(input("\tAssists: "))
po_rebounds = int(input("\tRebounds: "))
po_steals = int(input("\tSteals: "))
po_blocks = int(input("\tBlocks: "))
# Out:
# Playoffs:
# 	Points: 2749
# 	Assists: 449
# 	Rebounds: 648
# 	Steals: 164
# 	Blocks: 41

# %% [markdown]
# <h1> New player: </h1>

# %% [markdown]
# <h3> Libraries and files </h3>

# %%
import pandas as pd
import numpy as np
regular_season = pd.read_csv('Data_regular_season.csv')
playoffs = pd.read_csv('Data_playoffs.csv')
regular_season
# Out:
#                Player  Points  Assists  Rebounds  Steals  Blocks  \
# 0              LeBron   34241     9346      9405    2015     957
# 1                  MJ   32292     5633      6672    1944     893
# 2              Kareem   38387     5660     17440    1160    3189
# 3                Kobe   33643     6306      7047    1944     640
# 4         Karl_Malone   36928     5248     14968    2085    1145
# 5                Wilt   31419     4643     23924       0       0
# 6                Shaq   28596     3026     13099     739    2732
# 7              Duncan   26496     4225     15091    1025    3020
# 8                Dirk   31560     3651     11489    1210    1281
# 9              Hakeem   26946     3058     13748    2162    3820
# 10            Garnett   26071     5445     14662    1859    2037
# 11              Magic   17707    10141      6559    1724     374
# 12           Stockton   19711    15806      4051    3265     315
# ...

# %% [markdown]
# <h3> Function </h3>

# %% [markdown]
# <h4> Regular season </h4>

# %%
def createRSPlayer():
    element = {'Player':name,'Points':rs_points, 'Assists':rs_assists, 'Rebounds':rs_rebounds, 'Steals':rs_steals, 'Blocks':rs_blocks, 'Primary Position':primary_position}
    return regular_season.append(element,ignore_index=True)

# %% [markdown]
# <h4> Test: regular season </h4>

# %%
regular_season = createRSPlayer()
regular_season.to_csv('Data_regular_season.csv',index=False)
regular_season
# Out:
#                Player  Points  Assists  Rebounds  Steals  Blocks  \
# 0              LeBron   34241     9346      9405    2015     957
# 1                  MJ   32292     5633      6672    1944     893
# 2              Kareem   38387     5660     17440    1160    3189
# 3                Kobe   33643     6306      7047    1944     640
# 4         Karl_Malone   36928     5248     14968    2085    1145
# 5                Wilt   31419     4643     23924       0       0
# 6                Shaq   28596     3026     13099     739    2732
# 7              Duncan   26496     4225     15091    1025    3020
# 8                Dirk   31560     3651     11489    1210    1281
# 9              Hakeem   26946     3058     13748    2162    3820
# 10            Garnett   26071     5445     14662    1859    2037
# 11              Magic   17707    10141      6559    1724     374
# 12           Stockton   19711    15806      4051    3265     315
# ...

# %% [markdown]
# <h4> Playoffs </h4>

# %%
def createPlayoffsPlayer():
    element = {'Player':name,'Points':po_points,'Assists':po_assists,'Rebounds':po_rebounds,'Steals':po_steals,'Blocks':po_blocks, 'Primary Position':primary_position}
    return playoffs.append(element, ignore_index=True)

# %% [markdown]
# <h4> Test: playoffs </h4>

# %%
playoffs = createPlayoffsPlayer()
playoffs.to_csv('Data_playoffs.csv',index=False)
playoffs
# Out:
#                Player  Points  Assists  Rebounds  Steals  Blocks  \
# 0              LeBron    7491     1871      2348     445     250
# 1                  MJ    5987     1022      1152     376     158
# 2              Kareem    5762      767      2481     189     476
# 3                Kobe    5640     1040      1119     310     144
# 4         Karl_Malone    4761      610      2062     258     135
# 5                Wilt    3607      673      3913       0       0
# 6                Shaq    5250      582      2508     117     459
# 7              Duncan    5172      764      2859     168     568
# 8                Dirk    3663      360      1446     149     129
# 9              Hakeem    3755      458      1621     245     245
# 10            Garnett    2601      471      1534     178     186
# 11              Magic    3701     2346      1465     358      64
# 12           Stockton    2436     1839       608     338      50
# ...
